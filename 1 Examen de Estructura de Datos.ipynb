# %% [markdown]
# ## Ejercicio 1: Implementación de TADs
#
# ### Enunciado
# En este universo, cada entrenador tiene un equipo Pokémon. Para este ejercicio deberá implementar dos clases en Python: `Pokemon` y `Entrenador`.
#
# ### Clases a Implementar
#
# 1. **Clase `Pokemon`:**
#    - **Atributos:**
#      - `nombre`: *(str)* Nombre del Pokémon.
#      - `tipo`: *(str)* Tipo del Pokémon (por ejemplo, Agua, Fuego, Planta).
#      - `nivel`: *(int)* Nivel del Pokémon (debe estar entre 1 y 100).
#    - **Métodos:**
#      - `__init__()`: Constructor que inicializa los atributos del Pokémon.
#      - `subir_nivel()`: Método que incrementa el nivel del Pokémon en 1, siempre y cuando no supere el nivel 100.
#      - `__str__()`: Método que devuelve una representación en cadena del Pokémon en el formato:
#
#
# 2. **Clase `Entrenador`:**
#    - **Atributos:**
#      - `nombre`: *(str)* Nombre del entrenador.
#      - `equipo`: *(lista)* Lista que contiene instancias de la clase `Pokemon`.
#    - **Métodos:**
#      - `__init__()`: Constructor que inicializa el nombre del entrenador y crea una lista vacía para el equipo.
#      - `agregar_pokemon()`: Método que agrega un Pokémon al equipo. Si ya hay 6 Pokémon en el equipo, debe mostrar un mensaje indicando que no se pueden tener más Pokémon.
#      - `mostrar_equipo()`: Método que imprime todos los Pokémon del equipo utilizando el método `__str__` de la clase `Pokemon`.
#      - `nivel_promedio()`: Método que calcula y devuelve el nivel promedio de los Pokémon en el equipo. Si no hay Pokémon en el equipo, debe devolver 0.

# %%
#Ejercicio 1: Implementación de TADs

def __init__(self, nombre, tipo, nivel):
        if nivel < 1 or nivel > 100:
            raise ValueError("El nivel debe estar entre 1 y 100")
        self.nombre = nombre
        self.tipo = tipo
        self.nivel = nivel


def subir_nivel(self):

"""Incrementa el nivel del Pokémon en 1 sin superar el nivel 100"""

if self.nivel < 100:

self.nivel +=1

else:

print(f"{self.nombre} ({self.tipo}, Nivel: {self.nivel})"



class Entrenador:

def capturar_pokemon(self, pokemon):

"""Agrega un Pokémon al equipo del entrenador"""

if len(self.equipo) < 6:

     self.equipo.append(pokemon)

else:

     print("El equipo ya esta completo con 6 Pokemon.")



def mostar_equipo(self):

"""Muestra todos los Pokemones en el equipo"""

print(f"Equipo de {self.nombre}:")

  if len(self.equipo) == 0:

     print("No hay Pokemones en el equipo.")

else:

for pokemon in self. equipio:

      print(pokemon)





def __str__(self):

"""Devuelvbe una representacion en cadena del entrenador y nsu equipó"""

return f"Entrenador {self.nombre} con {len(self.equipo)} Pokemon."



# Crear algunos Pokémon 

pikachu = Pokemon("Pikachu", "Eléctrico", 25)

charizard = Pokemon("Charizard", "Fuego", 50)



# Crear un entrenador

ash = Entrenador("Ash ")

# Capturar Pokémon

ash.capturar_pokemon(pikachu)

ash.capturar_pokemon(charizard)

# Mostrar el equipo

ash.mostrar_equipo()

# Subir el nivel de Pikachu

pikachu.subir_nivel()

# Mostrar el equipo nuevamente

ash.mostrar_equipo()



#2. **Clase `Entrenador`:**

# Clase Pokemon (mantiene la misma estructura de antes)

class Pokemon:

    def __init__(self, nombre, tipo, nivel):

        if nivel < 1 or nivel > 100:

            raise ValueError("El nivel debe estar entre 1 y 100")

        self.nombre = nombre

        self.tipo = tipo

        self.nivel = nivel



    def subir_nivel(self):

        if self.nivel < 100:

            self.nivel += 1

        else:

            print(f"{self.nombre} ya está en el nivel máximo.")



    def __str__(self):

        return f"{self.nombre} ({self.tipo}, Nivel: {self.nivel})"





# Clase Entrenador

class Entrenador:

    def __init__(self, nombre):

        self.nombre = nombre

        self.equipo = []



    def agregar_pokemon(self, pokemon):

        """Agrega un Pokémon al equipo del entrenador si hay espacio (máximo 6)."""

        if len(self.equipo) < 6:

            self.equipo.append(pokemon)

        else:

            print("No se pueden tener más de 6 Pokémon en el equipo.")



    def mostrar_equipo(self):

        """Imprime todos los Pokémon en el equipo."""

        print(f"Equipo de {self.nombre}:")

        if not self.equipo:

            print("No hay Pokémon en el equipo.")

        else:

            for pokemon in self.equipo:

                print(pokemon)



    def nivel_promedio(self):

        """Calcula y devuelve el nivel promedio del equipo."""

        if not self.equipo:

            return 0

        total_niveles = sum(pokemon.nivel for pokemon in self.equipo)

        return total_niveles / len(self.equipo)



    def __str__(self):

        """Devuelve una representación en cadena del entrenador y su equipo."""

        return f"Entrenador {self.nombre} con {len(self.equipo)} Pokémon."

# Crear algunos Pokémon

pikachu = Pokemon("Pikachu", "Eléctrico", 25)

charizard = Pokemon("Charizard", "Fuego", 50)

bulbasaur = Pokemon("Bulbasaur", "Planta", 15)



# Crear un entrenador

ash = Entrenador("Ash Ketchum")



# Agregar Pokémon al equipo

ash.agregar_pokemon(pikachu)

ash.agregar_pokemon(charizard)

ash.agregar_pokemon(bulbasaur)



# Mostrar el equipo

ash.mostrar_equipo()



# Calcular y mostrar el nivel promedio del equipo

promedio = ash.nivel_promedio()

print(f"El nivel promedio del equipo de {ash.nombre} es: {promedio:.2f}")
# Out:
#   Cell In[4], line 13
#     """Incrementa el nivel del Pokémon en 1 sin superar el nivel 100"""
#     ^
# IndentationError: expected an indented block after function definition on line 11

# %% [markdown]
# # Ejercicio 2: Recursividad en el Universo Pokémon
#
# ## Enunciado
# Los entrenadores a menudo se enfrentan a desafíos que requieren la búsqueda de Pokémones en un área. Para este ejercicio implementar una función recursiva que simula la búsqueda de un Pokémon específico en un árbol de Pokémones.
#
# ### Contexto
# Suponga que tiene un árbol binario donde cada nodo representa un Pokémon, cada nodo tiene un nombre y puede tener hasta dos hijos (uno a la izquierda y otro a la derecha). La búsqueda de un Pokémon específico se puede realizar de manera recursiva verificando si el Pokémon se encuentra en el nodo actual o en uno de sus subárboles.
#
# ### Clases a Implementar
#
# 1. **Clase `PokemonNode`:**
#    - **Atributos:**
#      - `nombre`: *(str)* Nombre del Pokémon.
#      - `izquierda`: *(PokemonNode)* Hijo izquierdo (puede ser `None`).
#      - `derecha`: *(PokemonNode)* Hijo derecho (puede ser `None`).
#    - **Métodos:**
#      - `__init__(self, nombre: str)`: Constructor que inicializa el nombre del Pokémon y establece los hijos izquierdo y derecho como `None`.
#
# 2. **Función Recursiva `buscar_pokemon`:**
#    - **Parámetros:**
#      - `nodo`: *(PokemonNode)* Nodo actual del árbol donde se realiza la búsqueda.
#      - `nombre_pokemon`: *(str)* Nombre del Pokémon que se busca.
#    - **Retorno:**
#      - Devuelve `True` si el Pokémon es encontrado en el árbol, y `False` si no se encuentra.
#    - **Lógica:**
#      - Si el nodo actual es `None`, devuelve `False`.
#      - Si el nombre del nodo actual coincide con `nombre_pokemon`, devuelve `True`.
#      - Llama recursivamente a sí misma para buscar en el hijo izquierdo y luego en el hijo derecho.

# %%
class PokemonNode:

    def __init__(self, nombre: str):

        self.nombre = nombre

        self.izquierda = None

        self.derecha = None



def buscar_pokemon(nodo: PokemonNode, nombre_pokemon: str) -> bool:

    # Caso base: Si el nodo es None, no se encontró el Pokémon

    if nodo is None:

        return False

    # Si el nombre del nodo actual es el Pokémon que estamos buscando

    if nodo.nombre == nombre_pokemon:

        return True

    # Búsqueda recursiva en el hijo izquierdo y derecho

    encontrado_izquierda = buscar_pokemon(nodo.izquierda, nombre_pokemon)

    encontrado_derecha = buscar_pokemon(nodo.derecha, nombre_pokemon)

    return encontrado_izquierda or encontrado_derecha

# Crear los nodos del árbol

raiz = PokemonNode("Pikachu")

raiz.izquierda = PokemonNode("Charmander")

raiz.derecha = PokemonNode("Bulbasaur")

raiz.izquierda.izquierda = PokemonNode("Squirtle")

raiz.izquierda.derecha = PokemonNode("Jigglypuff")

raiz.derecha.derecha = PokemonNode("Meowth")

# Buscar algunos Pokémones

print(buscar_pokemon(raiz, "Jigglypuff"))  # True

print(buscar_pokemon(raiz, "Charizard"))   # False
# Out:
# True
# False

# %% [markdown]
# Pregunta 3
# Respuesta guardada
# Puntúa como 2,00
# Marcar pregunta
# Enunciado de la pregunta
# # Ejercicio 3: Sistema de Evoluciones de Pokémon
#
# ## Enunciado
# Cada Pokémon podría evolucionar a una forma más poderosa, para gestionarlas implementar un sistema utilizando una **pila** (stack), que permita llevar un registro de las evoluciones en orden inverso ya que la más reciente es la que se aplicará primero.
#
# ### Contexto
# La pila se utilizará para almacenar las evoluciones de un Pokémon. Cuando uno de ellos evoluciona, se agrega su nueva forma a la pila. Si el entrenador decide revertir la evolución se puede desapilar la forma más reciente.
#
# ### Clases a Implementar
#
# 1. **Clase `Evolucion`:**
#    - **Atributos:**
#      - `nombre`: *(str)* Nombre del Pokémon en su forma evolucionada.
#    - **Métodos:**
#      - `__init__(self, nombre: str)`: Constructor que inicializa el nombre de la evolución.
#
# 2. **Clase `PilaEvoluciones`:**
#    - **Atributos:**
#      - `evoluciones`: *(lista)* Lista enlazada que almacena las evoluciones en orden.
#    - **Métodos:**
#      - `__init__(self)`: Constructor que inicializa la lista de evoluciones como vacía.
#      - `apilar(self, evolucion: Evolucion)`: Método que agrega una evolución a la pila.
#      - `desapilar(self)`: Método que elimina y devuelve la última evolución agregada a la pila. Si la pila está vacía, debe devolver un mensaje indicando que no hay evoluciones para desapilar.
#      - `mostrar_evoluciones(self)`: Método que imprime todas las evoluciones en el orden en que fueron apiladas.

# %%
#Clase que representa una evolución de un Pokémon

class Evolucion:

    def __init__(self, nombre: str):

        self.nombre = nombre

    def __str__(self):

        return self.nombre

#Clase que representa una pila de evoluciones

class PilaEvoluciones:

    def __init__(self):

        #Inicializamos una lista vacía para almacenar las evoluciones

        self.evoluciones = []

    #Método para apilar una nueva evolución

    def apilar(self, evolucion: Evolucion):

        self.evoluciones.append(evolucion)

        print(f"Evolución '{evolucion}' añadida a la pila.")

    #Método para desapilar la evolución más reciente

    def desapilar(self):

        if len(self.evoluciones) > 0:

            evolucion_desap

# %% [markdown]
# Pregunta 4
# Respuesta guardada
# Puntúa como 4,00
# Marcar pregunta
# Enunciado de la pregunta
# # Ejercicio 4: Diseño Teórico de un Juego de Rol de Pokémon
#
# ## Enunciado
# Imagine que debe desarrollar un juego de rol basado en el universo Pokémon.
# Este juego incluirá elementos como la captura de Pokémon, batallas, gimnasios, insignias y la interferencia del equipo Rocket. Para cada uno de estos componentes deberá explicar, qué estructuras de datos utilizaría y por qué; considerando la eficiencia y eficacia en cada caso.
#
# ### Componentes mínimos del Juego a considerar
#
# 1. **Captura de Pokémon**
# 2. **Batallas**
# 3. **Gimnasios y Batallas por Insignias**
# 4. **Recorrido del Mapa**
# 5. **Interrupciones del Equipo Rocket**
#
# ### Consideraciones Finales
# Al diseñar este juego de rol es fundamental, considerar no solo, la estructura de datos más adecuada para cada componente sino también cómo estas estructuras interactúan entre sí. La elección de estructuras eficientes además de mejorar el rendimiento del juego también proporciona una mejor experiencia al jugador al permitir interacciones fluidas y rápidas. Este ejercicio debe ser desarrollado teóricamente como se discutió en clase, no en codificación; es decir, deben explicar que harían/implelemtarían en cada caso y porqué.

# %%
1. Mapa del Juego
Podrías representar el mapa como un grafo, donde cada nodo es una ciudad, ruta o lugar importante, y las aristas son los caminos que conectan estos lugares. Así podés diseñar diferentes rutas que el jugador puede tomar. Además, si querés agregar dificultad o tiempo de recorrido, podés usar pesos en las aristas para reflejar esas variaciones.

2. Gimnasios y Avance
Cada gimnasio sería otro nodo dentro del grafo, y las conexiones entre ellos representarían las rutas que el jugador debe seguir para llegar a cada uno. Podés hacer que ciertos gimnasios se desbloqueen solo cuando el jugador haya completado otros, permitiendo una progresión no lineal.

3. Eventos del Equipo Rocket
El Equipo Rocket podría aparecer en ciertos nodos o aristas del grafo, de manera que si el jugador pasa por un punto específico, se activa el evento. También podrías programar interrupciones aleatorias en ciertas rutas, lo que haría el juego más impredecible y emocionante.

4. Captura de Pokémon y Batallas
Aunque el sistema de captura y batallas no se relaciona directamente con grafos, podrías vincularlo al mapa. Por ejemplo, dependiendo de en qué nodo del grafo esté el jugador (ciudades, rutas, cuevas), aparecerían distintos Pokémon salvajes para capturar. De esta manera, podrías limitar ciertas especies a áreas específicas del mapa.

(Lo implemente con El grafo porque  te da la flexibilidad necesaria para diseñar el mapa del juego con distintas rutas y conexiones, además de integrar los gimnasios, eventos y zonas de captura del Pokémon).
